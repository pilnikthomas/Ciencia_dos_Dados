# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## THOMAS PILNIK
# ___

# %% [markdown]
# ## Análise da distribuição de internet no Brasil entre 2013 e 2015

# %% [markdown]
# ___
# ## Introdução
#
# Nas sociedades modernas difundir o conhecimento significa compartilhar o poder e, o acesso à informação é um direito de todos os cidadãos e um bom indicador do nível de desenvolvimento das sociedades. O compartilhamento das informações que é assegurado pelo acesso à internet são condições bastante significativas que contribuem para a melhoria de vida dos cidadãos.
#
# O objetivo desta análise é identificar os domicílios que possuem acesso a estas tecnologias e em qual velocidade estes serviços estão sendo cada vez mais utlizados pelos cidadãos/domicílios em cada uma das regiões do Brasil, assim como seu meio de acesso.
#
# Há um aumento do número de domicílios com internet no Brasil entre 2013, 2014 e 2015? Essas mudanças são mais ou menos acentuadas nas diferentes regiões do Brasil (Norte, Nordeste, Sul, Sudeste, Centro-Oeste)?
#
# Como a internet é acessada por domicílio no Brasil e em cada região? Há uma transição para o acesso via celular?
#
# A renda do país e das regiões seguem a mesma tendência do uso da internet?

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from numpy import zeros_like

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Thomas Pilnik\Ciência dos Dados\Projeto1

# %%
pnad13 = pd.read_csv('DOM2013.csv',sep=',')
pnad14 = pd.read_csv('DOM2014.csv',sep=',')
pnad15 = pd.read_csv('DOM2015.csv',sep=',')

# %%
pnad13.V4621=pnad13.V4621.astype('float')
pnad14.V4621=pnad14.V4621.astype('float')
pnad15.V4621=pnad15.V4621.astype('float')

# %%
pnad13.V02322=pnad13.V02322.astype('category')
pnad14.V02322=pnad14.V02322.astype('category')
pnad15.V02322=pnad15.V02322.astype('category')
pnad13.V02322.cat.categories=(['Sim', 'Não'])
pnad14.V02322.cat.categories=(['Sim', 'Não'])
pnad15.V02322.cat.categories=(['Sim', 'Não'])

# %%
pnad13.V02424=pnad13.V02424.astype('category')
pnad14.V02424=pnad14.V02424.astype('category')
pnad15.V02424=pnad15.V02424.astype('category')
pnad13.V02424.cat.categories=(['Sim', 'Não'])
pnad14.V02424.cat.categories=(['Sim', 'Não'])
pnad15.V02424.cat.categories=(['Sim', 'Não'])

# %%
pnad13.V0220=pnad13.V0220.astype('category')
pnad14.V0220=pnad14.V0220.astype('category')
pnad15.V0220=pnad15.V0220.astype('category')
pnad13.V0220.cat.categories=(['Sim', 'Não'])
pnad14.V0220.cat.categories=(['Sim', 'Não'])
pnad15.V0220.cat.categories=(['Sim', 'Não'])

# %%
pnad13.V02323=pnad13.V02323.astype('category')
pnad14.V02323=pnad14.V02323.astype('category')
pnad15.V02323=pnad15.V02323.astype('category')
pnad13.V02323.cat.categories=(['Sim', 'Não'])
pnad14.V02323.cat.categories=(['Sim', 'Não'])
pnad15.V02323.cat.categories=(['Sim', 'Não'])

# %%
pnad13.V0226=pnad13.V0226.astype('category')
pnad14.V0226=pnad14.V0226.astype('category')
pnad15.V0226=pnad15.V0226.astype('category')
pnad13.V0226.cat.categories=(['Sim', 'Não'])
pnad14.V0226.cat.categories=(['Sim', 'Não'])
pnad15.V0226.cat.categories=(['Sim', 'Não'])

# %%
pnad13.V02272=pnad13.V02272.astype('category')
pnad14.V02272=pnad14.V02272.astype('category')
pnad15.V02272=pnad15.V02272.astype('category')
pnad13.V02272.cat.categories=(['Sim', 'Não'])
pnad14.V02272.cat.categories=(['Sim', 'Não'])
pnad15.V02272.cat.categories=(['Sim', 'Não'])

# %%
pnad13_dataframe= pd.DataFrame(pnad13.loc[:, ["UF", "V02322","V0220", "V02323","V02424", "V4621"]])
pnad13_dataframe=pnad13_dataframe[pnad13_dataframe.V4621!=999999999999]
pnad13_dataframe.columns = ["UF", "INTERNET_DORMITORIO", "TEM_CELULAR", "INTERNET_COMPUTADOR","CELULAR_com_3G_4G", "RENDA"]

# %%
pnad14_dataframe= pd.DataFrame(pnad14.loc[:, ["UF", "V02322","V0220", "V02323", "V02424", "V4621"]])
pnad14_dataframe=pnad14_dataframe[pnad14_dataframe.V4621!=999999999999]
pnad14_dataframe.columns = ["UF", "INTERNET_DORMITORIO", "TEM_CELULAR", "INTERNET_COMPUTADOR","CELULAR_com_3G_4G", "RENDA"]

# %%
pnad15_dataframe= pd.DataFrame(pnad15.loc[:, ["UF", "V02322","V0220", "V02323","V02424", "V4621"]])
pnad15_dataframe=pnad15_dataframe[pnad15_dataframe.V4621!=999999999999]
pnad15_dataframe.columns = ["UF", "INTERNET_DORMITORIO", "TEM_CELULAR", "INTERNET_COMPUTADOR","CELULAR_com_3G_4G", "RENDA"]

# %%
pnad13_dataframe.loc[(pnad13_dataframe.UF==11)|(pnad13_dataframe.UF==12)|(pnad13_dataframe.UF==13)|(pnad13_dataframe.UF==14)|(pnad13_dataframe.UF==15)|(pnad13_dataframe.UF==16)|(pnad13_dataframe.UF==17), 'REGIAO']='Norte'
pnad13_dataframe.loc[(pnad13_dataframe.UF==21)|(pnad13_dataframe.UF==22)|(pnad13_dataframe.UF==23)|(pnad13_dataframe.UF==24)|(pnad13_dataframe.UF==25)|(pnad13_dataframe.UF==26)|(pnad13_dataframe.UF==27)|(pnad13_dataframe.UF==28)|(pnad13_dataframe.UF==29), 'REGIAO']='Nordeste'
pnad13_dataframe.loc[(pnad13_dataframe.UF==31)|(pnad13_dataframe.UF==32)|(pnad13_dataframe.UF==33)|(pnad13_dataframe.UF==35), 'REGIAO']='Sudeste'
pnad13_dataframe.loc[(pnad13_dataframe.UF==41)|(pnad13_dataframe.UF==42)|(pnad13_dataframe.UF==43), 'REGIAO']='Sul'
pnad13_dataframe.loc[(pnad13_dataframe.UF==50)|(pnad13_dataframe.UF==51)|(pnad13_dataframe.UF==52)|(pnad13_dataframe.UF==53), 'REGIAO']='Centro-Oeste'

pnad14_dataframe.loc[(pnad14_dataframe.UF==11)|(pnad14_dataframe.UF==12)|(pnad14_dataframe.UF==13)|(pnad14_dataframe.UF==14)|(pnad14_dataframe.UF==15)|(pnad14_dataframe.UF==16)|(pnad14_dataframe.UF==17), 'REGIAO']='Norte'
pnad14_dataframe.loc[(pnad14_dataframe.UF==21)|(pnad14_dataframe.UF==22)|(pnad14_dataframe.UF==23)|(pnad14_dataframe.UF==24)|(pnad14_dataframe.UF==25)|(pnad14_dataframe.UF==26)|(pnad14_dataframe.UF==27)|(pnad14_dataframe.UF==28)|(pnad14_dataframe.UF==29), 'REGIAO']='Nordeste'
pnad14_dataframe.loc[(pnad14_dataframe.UF==31)|(pnad14_dataframe.UF==32)|(pnad14_dataframe.UF==33)|(pnad14_dataframe.UF==35), 'REGIAO']='Sudeste'
pnad14_dataframe.loc[(pnad14_dataframe.UF==41)|(pnad14_dataframe.UF==42)|(pnad14_dataframe.UF==43), 'REGIAO']='Sul'
pnad14_dataframe.loc[(pnad14_dataframe.UF==50)|(pnad14_dataframe.UF==51)|(pnad14_dataframe.UF==52)|(pnad14_dataframe.UF==53), 'REGIAO']='Centro-Oeste'

pnad15_dataframe.loc[(pnad15_dataframe.UF==11)|(pnad15_dataframe.UF==12)|(pnad15_dataframe.UF==13)|(pnad15_dataframe.UF==14)|(pnad15_dataframe.UF==15)|(pnad15_dataframe.UF==16)|(pnad15_dataframe.UF==17), 'REGIAO']='Norte'
pnad15_dataframe.loc[(pnad15_dataframe.UF==21)|(pnad15_dataframe.UF==22)|(pnad15_dataframe.UF==23)|(pnad15_dataframe.UF==24)|(pnad15_dataframe.UF==25)|(pnad15_dataframe.UF==26)|(pnad15_dataframe.UF==27)|(pnad15_dataframe.UF==28)|(pnad15_dataframe.UF==29), 'REGIAO']='Nordeste'
pnad15_dataframe.loc[(pnad15_dataframe.UF==31)|(pnad15_dataframe.UF==32)|(pnad15_dataframe.UF==33)|(pnad15_dataframe.UF==35), 'REGIAO']='Sudeste'
pnad15_dataframe.loc[(pnad15_dataframe.UF==41)|(pnad15_dataframe.UF==42)|(pnad15_dataframe.UF==43), 'REGIAO']='Sul'
pnad15_dataframe.loc[(pnad15_dataframe.UF==50)|(pnad15_dataframe.UF==51)|(pnad15_dataframe.UF==52)|(pnad15_dataframe.UF==53), 'REGIAO']='Centro-Oeste'

# %% [markdown]
# # 1.1 Acesso à internet no Brasil (2013, 2014 e 2015)

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13.V02322.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet no Brasil em 2013")

plt.subplot(132)
plot = pnad14.V02322.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet no Brasil em 2014")

plt.subplot(133)
plot = pnad15.V02322.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet no Brasil em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos abaixo demonstram o acesso a internet por domicílio no país nos anos 2013, 2014 e 2015 respectivamente. Pode-se iterar que, por mais que mais da metade da população tenha acesso a internet desde 2013 (52.6%), o acesso a este meio não aumenta acentuadamente. De 2013 para 2014, o aumento foi de 2.2% e de 2013 para 2014 de 2.9%.

# %% [markdown]
# # 1.2 Acesso à internet por região do Brasil (2013, 2014 e 2015)

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Norte em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Norte em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Norte em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Nordeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Nordeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Nordeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Nordeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Nordeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Centro-Oeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Centro-Oeste em 2013")
plt.tight_layout()

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Centro-Oeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Centro-Oeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Centro-Oeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sudeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sudeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sudeste'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sudeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sudeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sul'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sul em 2013")
plt.tight_layout()

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sul'].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sul em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].INTERNET_DORMITORIO.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Acesso a internet na região Sul em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# As regiões Norte e Nordeste, em 2013, possuíam grande parte de seus domicílios sem acesso a internet (aproximandamente entre 62% e 64%). Em 2014, nessas regiões, há um acentuado avanço no acesso à internet, com um aumento de aproximadamente 10% em ambas regiões. Em 2015, ocorre mais um aumento nessa variável, porém com taxa menor (aproximandamente 1% no Norte e 2.5% no Nordeste): a região Norte atingiu 47,7% dos domicílios com internet e a região Nordeste atingiu 49,4%. Por mais que estes numeros ainda signifiquem que mais da metade dos domicílios não tinha acesso à internet em 2015, o avanço entre 10% e 14% de 2013 a 2015 é um bom sinal da dissiminação da técnologia.
#
# Na região Centro-Oeste, em 2013, o números de domicílios com e sem acesso à internet era bem equilibrado, com uma diferença de apenas 0.4%, comligeira vantagem aos domicílios sem internet. Em 2014, portanto, era de se esperar que esse número se alterasse e o número de domícilios com internet superasse o número de domicílios sem internet. Isso se confirma, com um aumento de mais de 7% de um ano ao outro. Em 2015, assim como visto nas regiões Norte e Nordeste, o aumento continua, porém em uma taxa menor. Assim, o acesso a internet na região Centro-Oeste chega a 61.8%, um aumento de 4% em relação a 2014 e 12% em relação a 2013.
#
# As regiões Sul e Sudeste, em 2013, já possuíam mais da metade de seus domicílios com acesso a internet (55.8% no Sudeste e 54% no Sul). Ambas regiões avançam relativamente próximas, sendo que em 2014 o Sudeste chega a 61.7% (aumento de 5.9%) e o Sul a 60.1% (aumento de 6.1%). Em 2015, como observado nas outras três regiões analisadas, o aumento no número de domicílios com acesso a internet diminui, sendo que a região Sudeste tem aumento de 3.4% em relação a 2014, atingindo 65.1% e a região Sul tem aumento de 2.9% em relação a 2014, atingindo 63% de seus domicílios com acesso a internet. De 2013 a 2015, a região Sudeste teve aumento de 9.3% e a região Sul de 9%.

# %% [markdown]
# # 2.1 Acesso à internet por microcomputador em 2013, 2014 e 2015
# ## 2.1.1 No Brasil

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe.INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet no Brasil em 2013")

plt.subplot(132)
plot = pnad14_dataframe.INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet computador no Brasil em 2014")

plt.subplot(133)
plot = pnad15_dataframe.INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet no Brasil em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima demonstram a frequência relativa de domicílios que acessam a internet por meio de microcomputador. Esse número diminuiu de 2013 a 2014 e de 2014 a 2015. Em 2013, 86.6% dos domicílios que tinham acesso a internet, acessavam-o por via de microcomputador. Esse número diminuiu para 74.2% em 2014 e 67.5% em 2015. Isso se deve, provavelmente, devido a migração ao uso do celular como aparelho de acesso à internet.

# %% [markdown]
# ## 2.1.2 Por região

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Norte 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Norte 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Norte 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Nordeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Nordeste 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Nordeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Nordeste 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Nordeste 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Centro-Oeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet reg. Centro-Oeste 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Centro-Oeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet reg. Centro-Oeste 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador internet reg. Centro-Oeste 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Sudeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sudeste 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Sudeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sudeste 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sudeste 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Sul"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sul 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Sul"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sul 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].INTERNET_COMPUTADOR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Microcomputador na internet reg. Sul 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima, dividos por região, mostram o uso de microcomputadores para acessar a internet em 2013, 2014 e 2015. Todas regiões demonstraram padrão similar: diminuição do uso de microcomputadores nos domicílios para acessar a internet. Este comportamento também é similar ao mostrado pelo Brasil como um todo nesse quesito (item 2.1.1).
# A diminuição mais acentuada ocorre no Nordeste, com queda de 24.7% em relação a frequência relativa da população da região.
# Isso deve-se a transição do acesso à internet por celulares com 3G e/ou 4G (assim como também via wi-fi fornecido por banda larga, no entanto, isso significa que o acesso por wi-fi pode estar acompanhado do acesso via wi-fi por microcomputadores).

# %% [markdown]
# # 3.1 Uso de celular no Brasil
# ## 3.1.1 Frequência relativa da posse de celulares em 2013, 2014 e 2015

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe.TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Freq. de pessoas com celular no Brasil em 2013")

plt.subplot(132)
plot = pnad14_dataframe.TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Freq. de pessoas com celular no Brasil em 2014")

plt.subplot(133)
plot = pnad15_dataframe.TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Freq de pessoas com celular no Brasil em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima mostram, para 2013, 2014 e 2015 respectivamente, a frequência relativa de pessoas no Brasil que possuem celulares. Como pode-se observar, o aumento é mínimo de 2013 até 2015, de apenas 1.6%, sendo o aumento de 2014 a 2015 de apenas 0.1%. Isso atesta que grande parte da população já possuí aparelhos celulares e a frequência está se estabilizando.

# %% [markdown]
# ## 3.1.2 Frequência relativa do uso de celulares para acessar a internet por 3G e/ou 4G (apenas inclui os domicílios que possuem celulares)

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(131)
plot = pnad13_dataframe.CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Uso celular (3G/4G) Brasil internet em 2013")

plt.subplot(132)
plot = pnad14_dataframe.CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Uso celular (3G/4G) Brasil internet em 2014")

plt.subplot(133)
plot = pnad15_dataframe.CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Uso celular (3G/4G) Brasil internet em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima demonstram, dentre os domicílios nos quais as pessoas possuem celular, quantas delas tem acesso à internet por meio deste aparelho e rede 3G ou 4G (excluindo conexões wi-fi a partir de banda larga). O gráfico para 2013 mostra que pouco mais da metade dos domicílios com aparelhos celulares não tinham acesso a internet por banda móvel (46.3% tinham acesso). Em 2014, o número muda acentuadamente, sendo que, nesse caso, 65.2% da população agora acessava a internet por meio de 3G e 4G. Esse aumento de 2013 a 2014 foi de 18.9%. Em 2015, como também foi visto no acesso a internet por domicílio, o aumento não cessa, porém diminui sua intensidade; nesse ano, o número de domicílios que acessam a internet por celular ligado a banda móvel é de 71%. O aumento de 2014 a 2015 foi de 5.8% (aproximadamente metade de 2013 a 2014). O aumento de 2013 a 2015 foi de 24.7%.

# %% [markdown]
# # 3.2 Uso de celular nas cinco regiões do país em 2013, 2014 e 2015
# ## 3.2.1 Posse de celular

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Norte em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Norte em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Norte em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Nordeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Nordeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Nordeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Nordeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Nordeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Centro-Oeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Centro-Oeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Centro-Oeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Centro-Oeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Centro-Oeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sudeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sudeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sudeste'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sudeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sudeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sul'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sul em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sul'].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sul em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].TEM_CELULAR.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Pessoas com celular reg. Sul em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima mostrama a frequência relativa sobre a posse de celulares nas regiões do Brasil em 2013, 2014 e 2015. É possivel iterar que em todas regiões, a grande maioria dos domicílios (número em torno de 85% ou mais) em 2013 ja possuí celulares. Esse número, em algumas regiões, aumenta levemente até 2015, como por exemplo no Sul, que em 2013 92.6% dos domicílios possuíam celulares e em 2015 94.3%. Em outras regiões, como Centro-Oeste, o número diminui 0.2% de 2014 a 2015, enquanto no Norte se mantém constante de 2014 a 2015.
# Os gráficos confirmam o comportamento do Brasil como um todo (3.1.1).

# %% [markdown]
# ## 3.2.2 Uso de celular com 3G/4G (banda móvel) para acesso da internet

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Norte em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Norte em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Norte em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Nordeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Nordeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Nordeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Nordeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Nordeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Centro-Oeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Centro-Oeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Centro-Oeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Centro-Oeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Centro-Oeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sudeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sudeste em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sudeste'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sudeste em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sudeste em 2015")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))

plt.subplot(131)
plot = pnad13_dataframe[pnad13_dataframe.REGIAO=='Sul'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('red', 'blue'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sul em 2013")

plt.subplot(132)
plot = pnad14_dataframe[pnad14_dataframe.REGIAO=='Sul'].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sul em 2014")

plt.subplot(133)
plot = pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].CELULAR_com_3G_4G.value_counts().plot(kind='pie', colors=('blue', 'red'), autopct="%0.1f",legend=True)
plt.title("Celular 3G/4G internet reg. Sul em 2015")

plt.tight_layout()
plt.show()

# %% [markdown]
# Os gráficos acima demonstram, dentre os domicílios nos quais as pessoas possuem celular, quantas delas tem acesso à internet por meio deste aparelho e rede 3G ou 4G (excluindo conexões wi-fi a partir de banda larga). Em todas regiões, vemos um aumento desse número. No Norte e no Nordeste, o aumento é menos acentuado, sendo de 2013 a 2015 11.1% e 14.4% respectivamente. No Centro-Oeste, o aumento é de 26.4%, no Sudeste 30.4% e no Sul 24.4%.
# Essa tendência explica a diminuição do uso de microcomputadores para o acesso a internet, o que será explorado mais detalhadamente na conclusão.

# %% [markdown]
# # 4.1 Renda
# ## 4.1.1 Histogramas de renda per capita do Brasil em 2013, 2014 e 2015

# %%
faixa=range(0,10000,1000)
renda13_cat=pd.cut(pnad13_dataframe.RENDA, bins=faixa)
renda14_cat=pd.cut(pnad14_dataframe.RENDA, bins=faixa)
renda15_cat=pd.cut(pnad15_dataframe.RENDA, bins=faixa)

# %%
plot=pnad13_dataframe.RENDA.plot.hist(bins=faixa, title="Renda Mensal per Capita em 2013", figsize=(6,6), alpha=0.9, color="b")
plt.show()

plot=pnad14_dataframe.RENDA.plot.hist(bins=faixa, title="Renda Mensal per Capita em 2014", figsize=(6,6), alpha=0.9, color="b")
plt.show()

plot=pnad15_dataframe.RENDA.plot.hist(bins=faixa, title="Renda Mensal per Capita em 2015", figsize=(6,6), alpha=0.9, color="b")
plt.show()

# %% [markdown]
# Os histogramas da renda per capita mensal de 2013, 2014 e 2015 permitem inferir que não há uma real mudança na distribuição de renda no país entre esses anos. Mais da metade da população ganha até 1000 reais por mês, e mais de 70% da população ganha até R$ 3000 por mês.

# %% [markdown]
# ## 3.1.2 Desigualdade salarial nas diferentes regiões (2013, 2014 e 2015)

# %%
a10=pd.DataFrame([pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Nordeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sudeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,35000)
plt.title("Dispersão de renda mensal per capita por região em 2013 (limite em 35000 reais)")
plt.show()

a10=pd.DataFrame([pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Nordeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sudeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,15000)
plt.title("Dispersão de renda mensal per capita por região em 2013 (limite em 15000 reais)")
plt.show()

a10=pd.DataFrame([pnad13_dataframe[pnad13_dataframe.REGIAO=="Norte"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Nordeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sudeste"].RENDA, pnad13_dataframe[pnad13_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,3000)
plt.title("Dispersão de renda mensal per capita por região em 2013 (limite em 3000 reais)")
plt.show()

a10=pd.DataFrame([pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Nordeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sudeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,35000)
plt.title("Dispersão de renda mensal per capita por região em 2014 (limite em 35000 reais)")
plt.show()

a10=pd.DataFrame([pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Nordeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sudeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,15000)
plt.title("Dispersão de renda mensal per capita por região em 2014 (limite em 15000 reais)")
plt.show()

a10=pd.DataFrame([pnad14_dataframe[pnad14_dataframe.REGIAO=="Norte"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Nordeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sudeste"].RENDA, pnad14_dataframe[pnad14_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,3000)
plt.title("Dispersão de renda mensal per capita por região em 2014 (limite em 3000 reais)")
plt.show()

a10=pd.DataFrame([pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,35000)
plt.title("Dispersão de renda mensal per capita por região em 2015 (limite em 35000 reais)")
plt.show()

a10=pd.DataFrame([pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,15000)
plt.title("Dispersão de renda mensal per capita por região em 2015 (limite em 15000 reais)")
plt.show()

a10=pd.DataFrame([pnad15_dataframe[pnad15_dataframe.REGIAO=="Norte"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Nordeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Centro-Oeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sudeste"].RENDA, pnad15_dataframe[pnad15_dataframe.REGIAO=="Sul"].RENDA],index=('Norte','Nordeste','Centro-Oeste','Sudeste','Sul'))
a10=a10.T
a10.plot.box()
plt.ylim(0,3000)
plt.title("Dispersão de renda mensal per capita por região em 2015 (limite em 3000 reais)")
plt.show()

# %% [markdown]
# Os gráficos de boxplot (vistos acima com diferentes escalas para melhor entendimento) permitem analisar as diferenças de renda nas diferentes regiões do país. É importante notar, primeiramente, que não há alterações significativas na distribuição de renda em cada umas das regiões nos diferentes anos.
#
# De 2013 a 2014, há um aumento visível na renda média nas regiões do Brasil, o que estagna de 2014 a 2015.
#
# Em 2015:
# No Norte, 50% da renda mensal per capita está entre 400 e 900 reais.
# No Nordeste, 50% da renda mensal per capita está entre 300 e 800 reais.
# No Centro-Oeste, 50% da renda mensal per capita está entre 600 e 1700 reais.
# No Sudeste, 50% da renda mensal per capita está entre 600 e 1600 reais.
# No Sul, 50% da rendna mensal per capita está entre 700 e 1750 reais.
#
# A partir disso, infere-se de que no Norte e Nordeste, a renda per capita por domicílio média é menor do que a mesma variável nas três outras regiôes. Esse fator impacta o uso da internet nessas regiões que, como visto anteriormente, é menor do que nas outras regiões do país.
#
# Os pontos pretos nos gráficos são exceções de domicílios com renda muito mais alta do que a distribuição de renda média do país e das regiões.

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# A partir da análise dos dados, pode-se perceber uma tendência sobre o uso da internet no país. A população, de maneira geral (o que se confirma analisando especificamente por região), está migrando para o uso da internet a partir de seus aparelhos celulares, conectados via 3G ou 4G, isto é, banda móvel, não dependendo de um wi-fi do domicílio. Ao mesmo tempo, podemos perceber o uso de microcomputadores para acessar a internet diminuindo, pois torna-se obsoleto utilizar um microcomputador (posição fixa, no domicílio) comparado a utilizar um aparelho celular, muito mais leve, portátil, acessível, etc.
#
# Também, de 2013 a 2014, vemos um aumento acentuado na renda per capita dos domicílios nas regiões de maneira geral, que pode ser diretamente relacionado ao aumento do uso de aparelhos celulares via banda móvel para utilizar a internet. Também, além do aumento do poder aquisitivo, de maneira geral, os celulares, ou mais especificamente smartphones, vem se tornando cada vez mais acessíveis, com opções novas no mercado a cada dia e por preços menores.
#
# Em 2015, a tendência continua em relação a migração dos microcomputadores para os celulares como principal meio de acessar a internet. Porém, a renda per capita dos domicílios estagna em seu aumento, o que pode ser relacionado com a diminuição do PIB (-3.77% de 2014 a 2015), assim como a diminuição do PIB per capita em -4,59% no mesmo período.
#
# Ainda assim, a distribuição de renda entre 2013, 2014 e 2015 no Brasil permaneceu virtualmente inalterada, mantendo uma situação de forte desigualdade social.
#
# Os dados brutos mostram que o acesso a internet no Brasil, de maneira geral, cresce a uma taxa pequena. Isso ocorre, principalmente, ao recuo do uso de microcomputadores para acessar a internet, ao mesmo tempo que a um aumento do uso de celulares/smartphones conectados a banda móvel. Dessa forma, os números quase que se "equilibram".
#
# Dessa forma, o acesso a internet (informação) não aumenta tão acentuadamente, no entanto, a maneira do acesso passa por uma forte transição, que significa também que a disponibilidade a informação aumenta largamente (um celular sempre conectado a banda móvel tem muito mais potêncial de acesso a internet do que um computador fixo em domicílio.
